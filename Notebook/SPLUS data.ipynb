# %%
import splusdata

# %%
conn = splusdata.connect("Luis", "andromeda*24") ## from splus.cloud
# Out:
# You have access to internal data

# %%
conn.get_tap_tables()
# Out:
# Tables and columns info at https://splus.cloud/

# %%
conn.twelve_band_img(156.19225, -18.64229, 300) ## Get 12 band image RA, DEC, Radius
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F570A13BF70>

# %%
conn.twelve_band_img(316.47314, -37.14452, 1000) ## Get 12 band image RA, DEC, Radius
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x7F570A083F40>

# %%
conn.get_cut(0.4, 0.7, 1500, 'R') ## image FITS cuts - RA, DEC, Radius, band
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f570a0a8460>, <astropy.io.fits.hdu.compressed.CompImageHDU object at 0x7f570a0a84f0>]

# %%
conn.get_field('STRIPE82-0002', 'R') ## Field image FITS - Field, band
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f570a0a8d60>, <astropy.io.fits.hdu.compressed.CompImageHDU object at 0x7f570a0a8730>]

# %%
conn.query('select id, ra, dec from dr2.detection_image where ra + dec > 200') ## async query on splus.cloud
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d13e6fe6bccb> in <module>
# ----> 1 conn.query('select id, ra, dec from dr2.detection_image where ra + dec > 200') ## async query on splus.cloud
#
# ~/anaconda3/lib/python3.8/site-packages/splusdata/__init__.py in query(self, query)
#      80         }
#      81
# ---> 82         res = requests.post(baselink , data = data, headers=headers)
#      83         xmldoc = minidom.parse(io.BytesIO(res.content))
#      84
#
# NameError: name 'headers' is not defined
