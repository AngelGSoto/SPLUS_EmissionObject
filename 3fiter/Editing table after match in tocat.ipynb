# %%
from astropy.table import Table, vstack

# %%
table = Table.read("emission_fornax.dat", format="ascii")

# %%
table.colnames
# Out:
# ['RA_1',
#  'DEC_1',
#  'Unnamed:_0',
#  'Field',
#  'ID',
#  'RA_2',
#  'DEC_2',
#  'FWHM',
#  'ISOarea',
#  'KRON_RADIUS',
#  'nDet_magPStotal',
#  'PhotoFlagDet',
#  'U_PStotal',
#  'F378_PStotal',
#  'F395_PStotal',
#  'F410_PStotal',
#  'F430_PStotal',
#  'G_PStotal',
#  'F515_PStotal',
#  'R_PStotal',
#  'F660_PStotal',
#  'I_PStotal',
#  'F861_PStotal',
#  'Z_PStotal',
#  'e_U_PStotal',
#  'e_F378_PStotal',
#  'e_F395_PStotal',
#  'e_F410_PStotal',
#  'e_F430_PStotal',
#  'e_G_PStotal',
#  'e_F515_PStotal',
#  'e_R_PStotal',
#  'e_F660_PStotal',
#  'e_I_PStotal',
#  'e_F861_PStotal',
#  'e_Z_PStotal',
#  'r_-_i',
#  'r_-_J0660',
#  'e(r_-_i)',
#  'e(r_-_J0660)',
#  'Unnamed:_0.1',
#  'GroupID',
#  'GroupSize',
#  'Separation']

# %%
table.remove_columns(['RA_1', 'DEC_1', 'Unnamed:_0'])

# %%
table.rename_column('RA_2', 'RA')
table.rename_column('DEC_2', 'DEC')

# %%
table
# Out:
# <Table length=191>
#    Field                ID            ... GroupSize     Separation
#    str12              str24           ...   int64        float64
# ------------ ------------------------ ... --------- ------------------
# SPLUS-s28s34 iDR3.SPLUS-s28s34.022345 ...       191 2338.8014167376687
# SPLUS-s25s32 iDR3.SPLUS-s25s32.034848 ...       191  21228.04478949848
# SPLUS-s25s33 iDR3.SPLUS-s25s33.041376 ...       191  16666.28765606227
# SPLUS-s26s31 iDR3.SPLUS-s26s31.032533 ...       191 17836.849502468012
# SPLUS-s26s32 iDR3.SPLUS-s26s32.032241 ...       191  17836.99216744791
# SPLUS-s26s32 iDR3.SPLUS-s26s32.032904 ...       191 14716.125556314042
# SPLUS-s26s35 iDR3.SPLUS-s26s35.008572 ...       191   6065.45085359378
# SPLUS-s26s36 iDR3.SPLUS-s26s36.045249 ...       191  11458.46004919481
# SPLUS-s27s33 iDR3.SPLUS-s27s33.013904 ...       191  6708.133734583175
# SPLUS-s27s35 iDR3.SPLUS-s27s35.013553 ...       191  6285.474926467379
# ...

# %%
table.write("Emission_lines_fornax.dat", format="ascii")

# %%
df_fornax = table.to_pandas()
df_fornax.to_csv("Emission_lines_fornax.csv")
