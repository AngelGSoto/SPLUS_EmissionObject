# %%
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
import pandas as pd
from astropy.table import Table, vstack
import hdbscan
from pathlib import Path
import seaborn as sns
import glob
import json
# %matplotlib inline
sns.set_color_codes()

# %%
table = Table.read("Good-LD-Halpha-DR3_noFlag_merge-takeoutbad-Final.ecsv", format="ascii.ecsv")
table["Field"]
# Out:
# <Column name='Field' dtype='str13' length=8720>
#    HYDRA-0027
#    HYDRA-0050
#  SPLUS-n15s22
#  SPLUS-n15s22
#    HYDRA-0017
#    HYDRA-0018
#    HYDRA-0020
#    HYDRA-0026
#    HYDRA-0041
#    HYDRA-0050
#    HYDRA-0065
#    HYDRA-0074
#           ...
# STRIPE82-0087
# STRIPE82-0087
# STRIPE82-0087
#  SPLUS-n02s24
#  SPLUS-s33s39
#  SPLUS-s34s40
#  SPLUS-s27s24
#  SPLUS-s27s24
#  SPLUS-s27s24
#  SPLUS-s27s24
#  SPLUS-n16s06
#  SPLUS-n17s15

# %%
list_ = []
for tab in table:
    if tab["Field"].startswith("HYDRA"):
        list_.append(tab)

# %%
merged_table = vstack(list_)

# %%
merged_table
# Out:
# <Table length=2356>
#    Field                ID            ...     P(GoodPho)          P(BadPho)
#    str13              str25           ...      float64             float64
# ------------ ------------------------ ... ------------------ -------------------
#   HYDRA-0027   iDR3.HYDRA-0027.003822 ...  0.535412358019262   0.464587641980738
#   HYDRA-0050   iDR3.HYDRA-0050.016160 ... 0.5553860876480267 0.44461391235197334
#   HYDRA-0017   iDR3.HYDRA-0017.040891 ... 0.5528104754987552 0.44718952450124483
#   HYDRA-0018   iDR3.HYDRA-0018.051257 ... 0.5354053702792487  0.4645946297207512
#   HYDRA-0020   iDR3.HYDRA-0020.053613 ... 0.5371199066798911   0.462880093320109
#   HYDRA-0026   iDR3.HYDRA-0026.043548 ... 0.5834479511306772 0.41655204886932284
#   HYDRA-0041   iDR3.HYDRA-0041.033431 ... 0.5693031231039277  0.4306968768960723
#   HYDRA-0050   iDR3.HYDRA-0050.017633 ... 0.5468846104633511  0.4531153895366488
# ...

# %%
#Converting the astropy table into pandas and saving
df_result = merged_table.to_pandas()

# %%
df_result.to_csv("Emission-objects-HYDRA.csv", index=False)
